# %%
from matplotlib import pyplot as plt
import struct as st
import numpy as np
from sklearn.preprocessing import StandardScaler

# %%
class NN:
    
    def __init__(self):
        self.st = [784, 128, 128, 10]
        self.W = {}
        self.b = {}
        self.dW = {}
        self.db = {}
        self.h = {}
        self.z = {}
        self.delta = {}
        self.iter = 0
        self.alpha = 0.25
        self.samples = 60000
        
    def f(self, x):
        return 1.0 / (1 + 1.0 * np.exp(-x))
    
    def f_d(self, x):
        return np.multiply(self.f(x), (1 - self.f(x)))
    
    def init_weights(self):        
        for l in range(1, len(self.st)):
            self.W[l] = np.random.uniform(-2,2,(self.st[l], self.st[l - 1]))
            self.b[l] = np.random.uniform(-2,2,(self.st[l], 1))
    
    def init_dels(self):    
        for l in range(1, len(self.st)):
            self.dW[l] = np.zeros((self.st[l], self.st[l - 1]))
            self.db[l] = np.zeros((self.st[l], 1))
    
    def feed_forward(self, inp):
        self.h[1] = inp
        for l in range(1, len(self.st)):
            self.z[l + 1] = self.W[l] @ self.h[l] + self.b[l]
            self.h[l + 1] = self.f(self.z[l + 1])
    
    def calc_d(self, out):
        self.delta[len(self.st)] = (self.h[len(self.st)] - out) 
        for l in range(len(self.st) - 1, 1, -1):
            self.delta[l] = (np.transpose(self.W[l])).dot(self.delta[l + 1])
            self.delta[l] = self.delta[l] * self.f_d(self.z[l])
    
    def accuracy(self, data):
        self.samples = np.shape(data)[0]
        ac = 0
        for i in range(self.samples):
            inp_image = np.reshape(data[i,1:].T, (784,1))
            inp_image = inp_image / 255.0
            self.feed_forward(inp_image)
            ind = int(data[i,0])
            ch = np.argmax(self.h[len(self.st)])
            if ind == ch:
                ac = ac + 1
        ac *= 100.0
        ac /= self.samples
        return ac
    
    def train(self, data):
        self.iter = 200
        self.alpha = 0.25
        self.samples = 10000
        acc = 0
        self.init_weights()
        for cnt in range(self.iter):
            self.init_dels()
            acc = acc * 100.0
            acc = acc / 60000
            print("Epoch: " + str(cnt) + " Running Accuracy: " + str(acc)) 
            acc = 0
            for i in range(60000):
                inp_image = np.reshape(data[i,1:].T, (784,1))
                inp_image = inp_image / 255.0
                self.feed_forward(inp_image)
                out = np.zeros((10,1))
                ind = int(data[i,0])
                out[ind] = 1
                ch = np.argmax(self.h[len(self.st)])
                self.calc_d(out)
                if ind == ch:
                    acc = acc + 1
                for l in range(1, len(self.st)):
                    self.db[l] = self.db[l] + self.delta[l + 1]
                    self.dW[l] = self.dW[l] +  self.delta[l + 1].dot(np.transpose(self.h[l]))
                if (i + 1) % 10000 == 0:
                    val = -(self.alpha * 1.0) / self.samples
                    for l in range(1, len(self.st)):
                        self.W[l] = self.W[l] + val * self.dW[l]
                        self.b[l] = self.b[l] + val * self.db[l]
                    self.init_dels()

# %%
data = np.loadtxt("mnist_train.csv" , delimiter = ",")
data2 = np.loadtxt("mnist_test.csv" , delimiter = ",")

# %%
new = NN()
new.train(data)
print("Accuracy on training data:")
print(new.accuracy(data))
print("Accuracy on testing data:")
print(new.accuracy(data2))
# Out:
# Epoch: 0 Running Accuracy: 0.0
# Epoch: 1 Running Accuracy: 13.013333333333334
# Epoch: 2 Running Accuracy: 19.731666666666666
# Epoch: 3 Running Accuracy: 25.415
# Epoch: 4 Running Accuracy: 30.706666666666667
# Epoch: 5 Running Accuracy: 35.115
# Epoch: 6 Running Accuracy: 39.085
# Epoch: 7 Running Accuracy: 42.51833333333333
# Epoch: 8 Running Accuracy: 45.46
# Epoch: 9 Running Accuracy: 48.075
# Epoch: 10 Running Accuracy: 50.25833333333333
# Epoch: 11 Running Accuracy: 52.14333333333333
# Epoch: 12 Running Accuracy: 53.89
# Epoch: 13 Running Accuracy: 55.46666666666667
# Epoch: 14 Running Accuracy: 56.885
# Epoch: 15 Running Accuracy: 58.18333333333333
# Epoch: 16 Running Accuracy: 59.3
# Epoch: 17 Running Accuracy: 60.266666666666666
# Epoch: 18 Running Accuracy: 61.22666666666667
# Epoch: 19 Running Accuracy: 62.14
# Epoch: 20 Running Accuracy: 62.945
# Epoch: 21 Running Accuracy: 63.685
# Epoch: 22 Running Accuracy: 64.42666666666666
# Epoch: 23 Running Accuracy: 65.03
# Epoch: 24 Running Accuracy: 65.65
# Epoch: 25 Running Accuracy: 66.32
# Epoch: 26 Running Accuracy: 66.89666666666666
# Epoch: 27 Running Accuracy: 67.42
# Epoch: 28 Running Accuracy: 67.92666666666666
# Epoch: 29 Running Accuracy: 68.41
# Epoch: 30 Running Accuracy: 68.87333333333333
# Epoch: 31 Running Accuracy: 69.335
# Epoch: 32 Running Accuracy: 69.72166666666666
# Epoch: 33 Running Accuracy: 70.06
# Epoch: 34 Running Accuracy: 70.39833333333333
# Epoch: 35 Running Accuracy: 70.78666666666666
# Epoch: 36 Running Accuracy: 71.12666666666667
# Epoch: 37 Running Accuracy: 71.45333333333333
# Epoch: 38 Running Accuracy: 71.78166666666667
# Epoch: 39 Running Accuracy: 72.09
# Epoch: 40 Running Accuracy: 72.37666666666667
# Epoch: 41 Running Accuracy: 72.73333333333333
# Epoch: 42 Running Accuracy: 72.99666666666667
# Epoch: 43 Running Accuracy: 73.26833333333333
# Epoch: 44 Running Accuracy: 73.51
# Epoch: 45 Running Accuracy: 73.765
# Epoch: 46 Running Accuracy: 74.005
# Epoch: 47 Running Accuracy: 74.24833333333333
# Epoch: 48 Running Accuracy: 74.43166666666667
# Epoch: 49 Running Accuracy: 74.66
# Epoch: 50 Running Accuracy: 74.85666666666667
# Epoch: 51 Running Accuracy: 75.07833333333333
# Epoch: 52 Running Accuracy: 75.295
# Epoch: 53 Running Accuracy: 75.50833333333334
# Epoch: 54 Running Accuracy: 75.68333333333334
# Epoch: 55 Running Accuracy: 75.86333333333333
# Epoch: 56 Running Accuracy: 76.045
# Epoch: 57 Running Accuracy: 76.23
# Epoch: 58 Running Accuracy: 76.40166666666667
# Epoch: 59 Running Accuracy: 76.58833333333334
# Epoch: 60 Running Accuracy: 76.755
# Epoch: 61 Running Accuracy: 76.90333333333334
# Epoch: 62 Running Accuracy: 77.08333333333333
# Epoch: 63 Running Accuracy: 77.22
# Epoch: 64 Running Accuracy: 77.375
# Epoch: 65 Running Accuracy: 77.52166666666666
# Epoch: 66 Running Accuracy: 77.68833333333333
# Epoch: 67 Running Accuracy: 77.83666666666667
# Epoch: 68 Running Accuracy: 77.96333333333334
# Epoch: 69 Running Accuracy: 78.09833333333333
# Epoch: 70 Running Accuracy: 78.22666666666667
# Epoch: 71 Running Accuracy: 78.38666666666667
# Epoch: 72 Running Accuracy: 78.54333333333334
# Epoch: 73 Running Accuracy: 78.655
# Epoch: 74 Running Accuracy: 78.80333333333333
# Epoch: 75 Running Accuracy: 78.91666666666667
# Epoch: 76 Running Accuracy: 79.03833333333333
# Epoch: 77 Running Accuracy: 79.14666666666666
# Epoch: 78 Running Accuracy: 79.25333333333333
# Epoch: 79 Running Accuracy: 79.355
# Epoch: 80 Running Accuracy: 79.475
# Epoch: 81 Running Accuracy: 79.565
# Epoch: 82 Running Accuracy: 79.65666666666667
# Epoch: 83 Running Accuracy: 79.78333333333333
# Epoch: 84 Running Accuracy: 79.88833333333334
# Epoch: 85 Running Accuracy: 79.99
# Epoch: 86 Running Accuracy: 80.09666666666666
# Epoch: 87 Running Accuracy: 80.18
# Epoch: 88 Running Accuracy: 80.26833333333333
# Epoch: 89 Running Accuracy: 80.34
# Epoch: 90 Running Accuracy: 80.40166666666667
# Epoch: 91 Running Accuracy: 80.51666666666667
# Epoch: 92 Running Accuracy: 80.58833333333334
# Epoch: 93 Running Accuracy: 80.69833333333334
# Epoch: 94 Running Accuracy: 80.78333333333333
# Epoch: 95 Running Accuracy: 80.87333333333333
# Epoch: 96 Running Accuracy: 80.95666666666666
# Epoch: 97 Running Accuracy: 81.04666666666667
# Epoch: 98 Running Accuracy: 81.11833333333334
# Epoch: 99 Running Accuracy: 81.18333333333334
# Epoch: 100 Running Accuracy: 81.26666666666667
# Epoch: 101 Running Accuracy: 81.36333333333333
# Epoch: 102 Running Accuracy: 81.47166666666666
# Epoch: 103 Running Accuracy: 81.545
# Epoch: 104 Running Accuracy: 81.625
# Epoch: 105 Running Accuracy: 81.69333333333333
# Epoch: 106 Running Accuracy: 81.765
# Epoch: 107 Running Accuracy: 81.84666666666666
# Epoch: 108 Running Accuracy: 81.905
# Epoch: 109 Running Accuracy: 81.98666666666666
# Epoch: 110 Running Accuracy: 82.06
# Epoch: 111 Running Accuracy: 82.11333333333333
# Epoch: 112 Running Accuracy: 82.19833333333334
# Epoch: 113 Running Accuracy: 82.265
# Epoch: 114 Running Accuracy: 82.36333333333333
# Epoch: 115 Running Accuracy: 82.41833333333334
# Epoch: 116 Running Accuracy: 82.475
# Epoch: 117 Running Accuracy: 82.55333333333333
# Epoch: 118 Running Accuracy: 82.61666666666666
# Epoch: 119 Running Accuracy: 82.685
# Epoch: 120 Running Accuracy: 82.74166666666666
# Epoch: 121 Running Accuracy: 82.80666666666667
# Epoch: 122 Running Accuracy: 82.85833333333333
# Epoch: 123 Running Accuracy: 82.91833333333334
# Epoch: 124 Running Accuracy: 82.98833333333333
# Epoch: 125 Running Accuracy: 83.04166666666667
# Epoch: 126 Running Accuracy: 83.09166666666667
# Epoch: 127 Running Accuracy: 83.14
# Epoch: 128 Running Accuracy: 83.20333333333333
# Epoch: 129 Running Accuracy: 83.23666666666666
# Epoch: 130 Running Accuracy: 83.30833333333334
# Epoch: 131 Running Accuracy: 83.35833333333333
