# %%
from matplotlib import pyplot as plt
import struct as st
import numpy as np
from sklearn.preprocessing import StandardScaler

# %%
class NN:
    
    def __init__(self):
        self.st = [784, 128, 10]
        self.W = {}
        self.b = {}
        self.dW = {}
        self.db = {}
        self.h = {}
        self.z = {}
        self.delta = {}
        self.iter = 0
        self.alpha = 0.25
        self.samples = 60000
        
    def f(self, x):
        return 1.0 / (1 + 1.0 * np.exp(-x))
    
    def f_d(self, x):
        return np.multiply(self.f(x), (1 - self.f(x)))
    
    def init_weights(self):        
        for l in range(1, len(self.st)):
            self.W[l] = np.random.uniform(-2,2,(self.st[l], self.st[l - 1]))
            self.b[l] = np.random.uniform(-2,2,(self.st[l], 1))
    
    def init_dels(self):    
        for l in range(1, len(self.st)):
            self.dW[l] = np.zeros((self.st[l], self.st[l - 1]))
            self.db[l] = np.zeros((self.st[l], 1))
    
    def feed_forward(self, inp):
        self.h[1] = inp
        for l in range(1, len(self.st)):
            self.z[l + 1] = self.W[l] @ self.h[l] + self.b[l]
            self.h[l + 1] = self.f(self.z[l + 1])
    
    def calc_d(self, out):
        self.delta[len(self.st)] = (self.h[len(self.st)] - out) 
        for l in range(len(self.st) - 1, 1, -1):
            self.delta[l] = (np.transpose(self.W[l])).dot(self.delta[l + 1])
            self.delta[l] = self.delta[l] * self.f_d(self.z[l])
    
    def accuracy(self, data):
        self.samples = np.shape(data)[0]
        ac = 0
        for i in range(self.samples):
            inp_image = np.reshape(data[i,1:].T, (784,1))
            inp_image = inp_image / 255.0
            self.feed_forward(inp_image)
            ind = int(data[i,0])
            ch = np.argmax(self.h[len(self.st)])
            if ind == ch:
                ac = ac + 1
        ac *= 100.0
        ac /= self.samples
        return ac
    
    def train(self, data):
        self.iter = 100
        self.alpha = 1
        self.samples = 10000
        acc = 0
        self.init_weights()
        for cnt in range(self.iter):
            self.init_dels()
            acc = acc * 100.0
            acc = acc / 60000
            print("Epoch: " + str(cnt) + " Running Accuracy: " + str(acc)) 
            acc = 0
            for i in range(60000):
                inp_image = np.reshape(data[i,1:].T, (784,1))
                inp_image = inp_image / 255.0
                self.feed_forward(inp_image)
                out = np.zeros((10,1))
                ind = int(data[i,0])
                out[ind] = 1
                ch = np.argmax(self.h[len(self.st)])
                self.calc_d(out)
                if ind == ch:
                    acc = acc + 1
                for l in range(1, len(self.st)):
                    self.db[l] = self.db[l] + self.delta[l + 1]
                    self.dW[l] = self.dW[l] +  self.delta[l + 1].dot(np.transpose(self.h[l]))
                if (i + 1) % 10000 == 0:
                    val = -(self.alpha * 1.0) / self.samples
                    for l in range(1, len(self.st)):
                        self.W[l] = self.W[l] + val * self.dW[l]
                        self.b[l] = self.b[l] + val * self.db[l]
                    self.init_dels()

# %%
data = np.loadtxt("mnist_train.csv" , delimiter = ",")
data2 = np.loadtxt("mnist_test.csv" , delimiter = ",")

# %%
new = NN()
new.train(data)
print("Accuracy on training data:")
print(new.accuracy(data))
print("Accuracy on testing data:")
print(new.accuracy(data2))
# Out:
# Epoch: 0 Running Accuracy: 0.0
# Epoch: 1 Running Accuracy: 24.343333333333334
# Epoch: 2 Running Accuracy: 40.625
# Epoch: 3 Running Accuracy: 51.53333333333333
# Epoch: 4 Running Accuracy: 58.37
# Epoch: 5 Running Accuracy: 63.055
# Epoch: 6 Running Accuracy: 66.29666666666667
# Epoch: 7 Running Accuracy: 68.79
# Epoch: 8 Running Accuracy: 70.86166666666666
# Epoch: 9 Running Accuracy: 72.51666666666667
# Epoch: 10 Running Accuracy: 73.96666666666667
# Epoch: 11 Running Accuracy: 75.10333333333334
# Epoch: 12 Running Accuracy: 76.13
# Epoch: 13 Running Accuracy: 77.00166666666667
# Epoch: 14 Running Accuracy: 77.74833333333333
# Epoch: 15 Running Accuracy: 78.43833333333333
# Epoch: 16 Running Accuracy: 79.02333333333333
# Epoch: 17 Running Accuracy: 79.605
# Epoch: 18 Running Accuracy: 80.14666666666666
# Epoch: 19 Running Accuracy: 80.64833333333333
# Epoch: 20 Running Accuracy: 81.11333333333333
# Epoch: 21 Running Accuracy: 81.54833333333333
# Epoch: 22 Running Accuracy: 81.96833333333333
# Epoch: 23 Running Accuracy: 82.28833333333333
# Epoch: 24 Running Accuracy: 82.58666666666667
# Epoch: 25 Running Accuracy: 82.92333333333333
# Epoch: 26 Running Accuracy: 83.175
# Epoch: 27 Running Accuracy: 83.47166666666666
# Epoch: 28 Running Accuracy: 83.72
# Epoch: 29 Running Accuracy: 83.96166666666667
# Epoch: 30 Running Accuracy: 84.18333333333334
# Epoch: 31 Running Accuracy: 84.42166666666667
# Epoch: 32 Running Accuracy: 84.67
# Epoch: 33 Running Accuracy: 84.85166666666667
# Epoch: 34 Running Accuracy: 85.04166666666667
# Epoch: 35 Running Accuracy: 85.245
# Epoch: 36 Running Accuracy: 85.405
# Epoch: 37 Running Accuracy: 85.59333333333333
# Epoch: 38 Running Accuracy: 85.74333333333334
# Epoch: 39 Running Accuracy: 85.88333333333334
# Epoch: 40 Running Accuracy: 86.00666666666666
# Epoch: 41 Running Accuracy: 86.17
# Epoch: 42 Running Accuracy: 86.295
# Epoch: 43 Running Accuracy: 86.415
# Epoch: 44 Running Accuracy: 86.56833333333333
# Epoch: 45 Running Accuracy: 86.71166666666667
# Epoch: 46 Running Accuracy: 86.83333333333333
# Epoch: 47 Running Accuracy: 86.94333333333333
# Epoch: 48 Running Accuracy: 87.03166666666667
# Epoch: 49 Running Accuracy: 87.11833333333334
# Epoch: 50 Running Accuracy: 87.215
# Epoch: 51 Running Accuracy: 87.33333333333333
# Epoch: 52 Running Accuracy: 87.44333333333333
# Epoch: 53 Running Accuracy: 87.53666666666666
# Epoch: 54 Running Accuracy: 87.63666666666667
# Epoch: 55 Running Accuracy: 87.745
# Epoch: 56 Running Accuracy: 87.81666666666666
# Epoch: 57 Running Accuracy: 87.885
# Epoch: 58 Running Accuracy: 87.96166666666667
# Epoch: 59 Running Accuracy: 88.04
# Epoch: 60 Running Accuracy: 88.11166666666666
# Epoch: 61 Running Accuracy: 88.2
# Epoch: 62 Running Accuracy: 88.30333333333333
# Epoch: 63 Running Accuracy: 88.37166666666667
# Epoch: 64 Running Accuracy: 88.43833333333333
# Epoch: 65 Running Accuracy: 88.51333333333334
# Epoch: 66 Running Accuracy: 88.56666666666666
# Epoch: 67 Running Accuracy: 88.63666666666667
# Epoch: 68 Running Accuracy: 88.69833333333334
# Epoch: 69 Running Accuracy: 88.76833333333333
# Epoch: 70 Running Accuracy: 88.835
# Epoch: 71 Running Accuracy: 88.89
# Epoch: 72 Running Accuracy: 88.93333333333334
# Epoch: 73 Running Accuracy: 88.99333333333334
# Epoch: 74 Running Accuracy: 89.05333333333333
# Epoch: 75 Running Accuracy: 89.11166666666666
# Epoch: 76 Running Accuracy: 89.18
# Epoch: 77 Running Accuracy: 89.21333333333334
# Epoch: 78 Running Accuracy: 89.27166666666666
# Epoch: 79 Running Accuracy: 89.33833333333334
# Epoch: 80 Running Accuracy: 89.38166666666666
# Epoch: 81 Running Accuracy: 89.42666666666666
# Epoch: 82 Running Accuracy: 89.48
# Epoch: 83 Running Accuracy: 89.51333333333334
# Epoch: 84 Running Accuracy: 89.55
# Epoch: 85 Running Accuracy: 89.58833333333334
# Epoch: 86 Running Accuracy: 89.65333333333334
# Epoch: 87 Running Accuracy: 89.70333333333333
# Epoch: 88 Running Accuracy: 89.745
# Epoch: 89 Running Accuracy: 89.78
# Epoch: 90 Running Accuracy: 89.84666666666666
# Epoch: 91 Running Accuracy: 89.88166666666666
# Epoch: 92 Running Accuracy: 89.93
# Epoch: 93 Running Accuracy: 89.97166666666666
# Epoch: 94 Running Accuracy: 90.01833333333333
# Epoch: 95 Running Accuracy: 90.06666666666666
# Epoch: 96 Running Accuracy: 90.10333333333334
# Epoch: 97 Running Accuracy: 90.13666666666667
# Epoch: 98 Running Accuracy: 90.185
# Epoch: 99 Running Accuracy: 90.21333333333334
# Accuracy on training data:
# 90.28833333333333
# Accuracy on testing data:
# 89.94
